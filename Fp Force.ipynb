# %%
weight_sa = 1.43 #Surge Arrester
weight_pi = 1.16 #post-insulator

ca = 0.44*1.49
ip = 1.00
wp = weight_sa + weight_pi

fp = 4*ca*ip*wp
V = 0.56*ca*wp*ip
print('Seismic Force =  ' + str(fp) + " kN")
print('Seismic Force =  ' + str(V) + " kN")
# Out:
# Seismic Force =  6.792015999999999 kN
# Seismic Force =  0.95088224 kN
