# %%
import math
import pandas as pd

# %% [markdown]
# ## Vertical Irregularites
#
# 1. Stiffness irregularity-soft story
# 2. Weight (mass) irregularity
# 3. Vertical geometric irregularity
# 4. In-plane discontinuity in vertical lateral-force resisting element
# 5. Discontinuity in capacity-weak story

# %% [markdown]
# ### Stiffness Irregularity - Soft story
# 1. The story stiffness is less than 70 percent of that of the story above.
# 2. The story stiffness is less than 80 percent of the average stiffness of the three stories above.
#
# All seismic story drifts were obtained directly from MIDAS and expressed in terms of 1/x, where x is the reciprocal of the story drift ratio. The tolerable drift was calculated and reduced by the amplification for inelastic drift which is 0.7R.

# %%
driftf = pd.read_excel('test.xls')
driftf
# length = len(driftf)

# stiff = 462.67/0.0048
# print(stiff)

# i = 0 
# while i < length:
#     print(i)
#     i += 1

# driftf['Displacement(X)']

# drift = [
#     driftf[3]
# ]

# print(driftf[3])
# xl = pd.ExcelFile(path)
# print(xl.sheet_names)

# displacement = [0.71,1.08,1.45,1.75,2.02]
# height = [12,12,12,12,12]
# story_height = []

# def driftSolve(d,ht):
#     value = d/ht
#     return value

# total_height = 0

# for i in height:
#     total_height = total_height + i
#     story_height.append(total_height)

# df = pd.DataFrame({
#       'Story Height': height,
#       'building Height': story_height,
#       'Displacement': displacement,
#       })
# df
# Out:
#     Unnamed: 0  Unnamed: 1 Module Load Case  Node      Story  Level\n(m)  \
# 0          NaN         NaN   Base     gLCB4  1556       ROOF       37.02
# 1          NaN         NaN   Base     gLCB4  1498  MEZZANINE       33.72
# 2          NaN         NaN   Base     gLCB4  1488         9F       30.53
# 3          NaN         NaN   Base     gLCB4   968         8F       26.83
# 4          NaN         NaN   Base     gLCB4   894         7F       23.13
# 5          NaN         NaN   Base     gLCB4   820         6F       19.43
# 6          NaN         NaN   Base     gLCB4   746         5F       15.73
# 7          NaN         NaN   Base     gLCB4   672         4F       12.03
# 8          NaN         NaN   Base     gLCB4   598         3F        8.33
# 9          NaN         NaN   Base     gLCB4   510         2F        4.63
# 10         NaN         NaN   Base     gLCB4   431         GF        0.00
# 11         NaN         NaN   Base     gLCB4     0   BASEMENT       -4.60
#
# ...
