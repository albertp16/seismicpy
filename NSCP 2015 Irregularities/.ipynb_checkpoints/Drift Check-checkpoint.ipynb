# %%
import math
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
import numpy as np

# %% [markdown]
# ## Seismic Story Drift
#
# All seismic story drifts were obtained directly from MIDAS and expressed in terms of 1/x, where x is the reciprocal of the story drift ratio. The tolerable drift was calculated and reduced by the amplification for inelastic drift which is 0.7R.

# %%
def driftSolve(dtop,dbot,ht):
    value = (dtop-dbot)/ht
    return value

displacement_f = pd.read_excel('displacement.xls')

length = len(displacement_f)

height = []
displacement = []

dtop = []
dbot = []
drift_ht = []
i = 0
while i < length:

    story_index = displacement_f['story'][i]

    disp = displacement_f['max'][i]
    dtop.append(disp)
    n_slice = length - 2
    if i < n_slice:
        disp_lower = displacement_f['max'][i+1]
        dbot.append(disp_lower)
    else:
        dbot.append(0)  
        
    drift_ht.append(story_index)
    i = i + 1

x_graph = []
y_graph = []
drift_data = []
i = 0
length2 = len(dtop)
while i < length2:
    level_index = displacement_f['level'][i]
    if i != 0:
        elastic_drift = driftSolve(dtop[i],dbot[i],drift_ht[i])
        inelastic_drift = elastic_drift*8.5*0.7
        drift_data.append(inelastic_drift)
        x_graph.append((1/elastic_drift))
        y_graph.append(level_index)
        
    i = i + 1
edlx = [300,300]
edly = [0,35]

plt.figure(figsize=(5, 5))
plt.plot(x_graph, y_graph, label = "Elastic Drift", color="red")
plt.plot(edlx, edly, label = "Elastic Drift Limit", color="blue", linestyle="dashed")
plt.legend()
plt.grid()
plt.title("Seismic Drift Values Response Spectrum Case X-Direction")
plt.xlabel("1/ Drift Ratio")
plt.ylabel("Elevation (m)")
plt.show()

# %%
edlx = [0.02,0.02]
edly = [0,35]

plt.figure(figsize=(6, 6))
plt.plot(drift_data, y_graph, label = "Inelastic Drift", color="red")
plt.plot(edlx, edly, label = "Inelastic Drift Limit", color="blue", linestyle="dashed")
plt.legend()
plt.grid()
plt.title("Seismic Drift Values (Diaphragm Drifts)")
plt.xlabel("Drift")
plt.ylabel("Elevation (m)")
plt.show()

# %% [markdown]
# ## Story Shear
# (Response Spectrum Case)

# %%
ssrsf = pd.read_excel('rsshear.xls')

length = len(ssrsf)

height = []
shear_major = []
shear_ortho = []


i = 0
while i < length:
    case_index = ssrsf['case'][i]
    if(case_index == 'RS-Major(RS)'):
        height.append(ssrsf['height'][i])    
    i = i + 1
i = 0
while i < length:
    case_index = ssrsf['case'][i]
    if(case_index == 'RS-Major(RS)'):
        shear_x = ssrsf['X'][i]
        shear_y = ssrsf['Y'][i]
        resultant = math.sqrt(math.pow(shear_x,2) + math.pow(shear_y,2))
        shear_major.append(resultant)
    if(case_index == 'RS-Ortho(RS)'):
        shear_x = ssrsf['X'][i]
        shear_y = ssrsf['Y'][i]
        resultant = math.sqrt(math.pow(shear_x,2) + math.pow(shear_y,2))
        shear_ortho.append(resultant)     
    i = i + 1
    

plt.figure(figsize=(8, 8))
plt.step(shear_major, height, label = "X-direction", color="red")
plt.step(shear_ortho, height, label = "Y-direction", color="blue")
plt.legend()
plt.grid()
plt.title("Seismic Story Shear Response Spectrum Case \n Azzuro Hotel")
plt.xlabel("Storey Shear (kN)")
plt.ylabel("Elevation (m)")
plt.show()

# %% [markdown]
# ## Overturning Moment

# %%
length = len(shear_major)
OT_major = []
OT_ortho = []
OT_height = []
ot_at_x = 0
ot_at_y = 0
i = 0

while i < length:
    height_index = height[i]
    if height_index > 0:
        major = shear_major[i]*height[i]
        ortho = shear_ortho[i]*height[i]
        ot_at_x = ot_at_x + major
        ot_at_y = ot_at_y + ortho
        OT_major.append(ot_at_x)
        OT_ortho.append(ot_at_y)
        OT_height.append(height[i])
    i = i + 1
    
plt.figure(figsize=(8, 8))
plt.plot(OT_major, OT_height, label = "Bending about X", color="red")
plt.plot(OT_ortho, OT_height, label = "Bending about Y", color="blue")
plt.grid()
plt.legend()
plt.title("Seismic Overturning Moment Response Spectrum Case \n Azzuro Hotel")
plt.xlabel("Overturning Moment (kN-m)")
plt.ylabel("Elevation (m)")

plt.show()

# %% [markdown]
# ### Soft Story

# %%
level = [
'ROOF',
'MEZZANINE',
'9F',
'8F',
'7F',
'6F',
'5F',
'4F',
'3F',
'2F',
]


mass= [
# 1172.884,
4255.109,
10617.116,
9680.435,
9494.811,
9606.123,
10144.229,
10260.914,
10389.003,
16431.240,
]

def massIrreg(m1,m2):
    if m1 < m2:
        return 'ok'
    else:
        return 'irregular'

mass_above_arr = []
mass_below_arr = []
# mass_remarks =
mass_length = len(mass)
i = 0
while i < mass_length:
    mass_level = mass[i]
    mass_bot = mass_length - 1 ##Top floor
    mass_top = 0
    below_index = i + 1
    above_index = i - 1    
    if i == mass_top:
        below_ratio = mass_level / (mass[below_index]*1.5) 
#         above_ratio = (mass[above_index]*1.5) / mass_level
        mass_below_arr.append(below_ratio)
        mass_above_arr.append(0)
    elif i == mass_bot:
#         below_ratio = (mass[below_index]*1.5) / mass_level
        above_ratio = mass_level / (mass[above_index]*1.5)        
        mass_below_arr.append(0)
        mass_above_arr.append(above_ratio)
    else:
        below_ratio = mass_level /(mass[below_index]*1.5) 
        above_ratio = mass_level /(mass[above_index]*1.5) 
        mass_below_arr.append(below_ratio)
        mass_above_arr.append(above_ratio)     
    i = i + 1
# mass[0].append(1172.884)
mass.insert (0, 1172.884)
mass_below_arr.insert (0, "N/A")
mass_above_arr.insert (0, "N/A")
# mass_below_arr[0].append('N/A')
# mass_above_arr[0].append('N/A')
print(mass_above_arr)
print(mass_below_arr)

df = pd.DataFrame({
      'Level' : level,    
      'Mass' : mass,
      'Below': mass_below_arr,
      'Above': mass_above_arr,
      })
df
# Out:
# ['N/A', 0, 1.6634303218397772, 0.6078508827946623, 0.6538832190908777, 0.6744823040711395, 0.7040113200021834, 0.6743350661083591, 0.6749887972942761, 1.0543995415151965]
# ['N/A', 0.26718548929232133, 0.7311734786022873, 0.6797000312416259, 0.6589415938146951, 0.631302980246207, 0.6590854706835407, 0.6584471419763122, 0.42151426185729135, 0]
#        Level       Mass     Below     Above
# 0       ROOF   1172.884       N/A       N/A
# 1  MEZZANINE   4255.109  0.267185         0
# 2         9F  10617.116  0.731173   1.66343
# 3         8F   9680.435    0.6797  0.607851
# 4         7F   9494.811  0.658942  0.653883
# 5         6F   9606.123  0.631303  0.674482
# 6         5F  10144.229  0.659085  0.704011
# 7         4F  10260.914  0.658447  0.674335
# 8         3F  10389.003  0.421514  0.674989
# 9         2F  16431.240         0    1.0544
