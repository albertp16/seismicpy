# %%
import math
import pandas as pd

# %% [markdown]
# ### Seismic Story Drift
#
# All seismic story drifts were obtained directly from MIDAS and expressed in terms of 1/x, where x is the reciprocal of the story drift ratio. The tolerable drift was calculated and reduced by the amplification for inelastic drift which is 0.7R.

# %% [markdown]
# ## Story Shear
# (Response Spectrum Case)

# %%
ssrsf = pd.read_excel('rsshear.xls')
# ssrsf
print(ssrsf)
# length = len(ssrsf)

height = []
shear_x = []
shear_y = []
i = 0
while i < length:
    case_index = ssrsf['case'][i]
    if(case_index == 'RS-Major(RS)'):
        shear_x.append(ssrsf['X'][i])
        height.append(ssrsf[4][i])
    if(case_index == 'RS-Ortho(RS)'):
        shear_y.append(ssrsf['Y'][i])        
    i = i + 1
# print(height)
# print(shear_x)
print(shear_y)
# Out:
#     Unnamed: 0   1   2          3        4          case        6        7  8  \
# 0          NaN NaN NaN       ROOF  37.0215  RS-Major(RS)   10.934   151.70  0
# 1          NaN NaN NaN  MEZZANINE  33.7175  RS-Major(RS)   18.856   303.31  0
# 2          NaN NaN NaN         9F  30.5300  RS-Major(RS)   25.874   656.02  0
# 3          NaN NaN NaN         8F  26.8300  RS-Major(RS)   28.098   611.19  0
# 4          NaN NaN NaN         7F  23.1300  RS-Major(RS)   38.236   616.23  0
# 5          NaN NaN NaN         6F  19.4300  RS-Major(RS)   29.164   580.41  0
# 6          NaN NaN NaN         5F  15.7300  RS-Major(RS)   23.877   600.72  0
# 7          NaN NaN NaN         4F  12.0300  RS-Major(RS)   31.929   606.61  0
# 8          NaN NaN NaN         3F   8.3300  RS-Major(RS)   25.525   596.74  0
# 9          NaN NaN NaN         2F   4.6300  RS-Major(RS)   38.743   823.82  0
# 10         NaN NaN NaN         GF   0.0000  RS-Major(RS)   26.236   330.50  0
# ...
