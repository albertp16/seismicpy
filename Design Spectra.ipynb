# %%
# import matplotlib
import matplotlib.pyplot as plt

import NSCP_2015 as NSCP
import ASCE705 as ASCE


def generate(ca,cv,R):
      
    data = NSCP.rsCurve(ca,cv,R)  
    fig, ax = plt.subplots(figsize=(10,10))
    ax.plot(data['elastic']['x'], data['elastic']['y'], label = "NSCP 2015")
    
    ax.set(xlabel="Period (sec)", ylabel="Spectral Acceleration (Sa)",
            title= "Design Response Spectra")
    ax.grid()
    plt.xscale('line')
    plt.legend()
    plt.show()
    
test = NSCP.siteCoef(33,"A","s_d","4")
ca = test.ca()
cv = test.cv()
R = 8.5
generate(ca,cv,R)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22460\3175574389.py in <module>
#      23 cv = test.cv()
#      24 R = 8.5
# ---> 25 generate(ca,cv,R)
#
# ~\AppData\Local\Temp\ipykernel_22460\3175574389.py in generate(ca, cv, R)
#      15             title= "Design Response Spectra")
#      16     ax.grid()
# ---> 17     plt.xscale('line')
#      18     plt.legend()
#      19     plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in xscale(value, **kwargs)
#    3059 @_copy_docstring_and_deprecators(Axes.set_xscale)
#    3060 def xscale(value, **kwargs):
# -> 3061     return gca().set_xscale(value, **kwargs)
#    3062
#    3063
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in set_xscale(self, value, **kwargs)
#    3784         g = self.get_shared_x_axes()
#    3785         for ax in g.get_siblings(self):
# -> 3786             ax.xaxis._set_scale(value, **kwargs)
#    3787             ax._update_transScale()
#    3788             ax.stale = True
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in _set_scale(self, value, **kwargs)
#     759     def _set_scale(self, value, **kwargs):
#     760         if not isinstance(value, mscale.ScaleBase):
# --> 761             self._scale = mscale.scale_factory(value, self, **kwargs)
#     762         else:
#     763             self._scale = value
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\scale.py in scale_factory(scale, axis, **kwargs)
#     594             "since %(since)s and support will be removed %(removal)s.")
#     595         scale = scale.lower()
# --> 596     scale_cls = _api.check_getitem(_scale_mapping, scale=scale)
#     597     return scale_cls(axis, **kwargs)
#     598
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\_api\__init__.py in check_getitem(_mapping, **kwargs)
#     186         return mapping[v]
#     187     except KeyError:
# --> 188         raise ValueError(
#     189             "{!r} is not a valid value for {}; supported values are {}"
#     190             .format(v, k, ', '.join(map(repr, mapping)))) from None
#
# ValueError: 'line' is not a valid value for scale; supported values are 'linear', 'log', 'symlog', 'logit', 'function', 'functionlog'
