# %%
import apecseismicpy.aci350.hydrodynamic as sd
import math

tslab = 150 #mm
fc = 20.68 
ec = 4700*math.sqrt(fc) 
gamma_l = 10.10

l = 7.2 #tank dimension perpendicular 
b = 14.5 # tank dimension perpendicular 
hl = 7.15
liquid_weight = l*b*hl*gamma_l
print(liquid_weight)

print("Weight of Accelarting Liquids Section")
tank = sd.effective_liquid_weights(l,hl,liquid_weight)
print(tank)
print("Weight of Accelarting Liquids Section")
contriods = sd.calculate_heights_of_centers_of_gravity(l,hl)
print(contriods)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import apecseismicpy.aci350.hydrodynamic as sd
#       2 import math
#       4 tslab = 150 #mm
#
# File c:\Users\alber\OneDrive\OLD FILES NOV 2022\Desktop\codes\seismicpy\apecseismicpy\__init__.py:5
#       3 from .nscp2015.period import calculateStructuralPeriod
#       4 from .nscp2015.baseshear import calculate_base_shear
# ----> 5 from .aci350.hydrodynamic import effective_liquid_weights
#
# File c:\Users\alber\OneDrive\OLD FILES NOV 2022\Desktop\codes\seismicpy\apecseismicpy\aci350\__init__.py:1
# ----> 1 from .hydrodynamic import effective_liquid_weights
#
# File c:\Users\alber\OneDrive\OLD FILES NOV 2022\Desktop\codes\seismicpy\apecseismicpy\aci350\hydrodynamic\__init__.py:2
#       1 from .loads import effective_liquid_weights,calculate_heights_of_centers_of_gravity
# ----> 2 from .period import dynamicProperties
#
# ImportError: cannot import name 'dynamicProperties' from 'apecseismicpy.aci350.hydrodynamic.period' (c:\Users\alber\OneDrive\OLD FILES NOV 2022\Desktop\codes\seismicpy\apecseismicpy\aci350\hydrodynamic\period.py)
