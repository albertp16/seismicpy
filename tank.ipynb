# %%
import apecseismicpy.aci350.hydrodynamic as hydrodynamic
import math

tslab = 150 #mm
fc = 20.68 
ec = 4700*math.sqrt(fc) 
gamma_l = 9.81

l = 7.2 #tank dimension perpendicular 
b = 14.5 # tank dimension perpendicular 
hl = 7.15


tank = hydrodynamic.calculate_heights_of_centers_of_gravity(l,hl)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 14
#      10 b = 14.5
#      11 hl = 7.15
# ---> 14 tank = hydrodynamic.calculate_heights_of_centers_of_gravity(l,hl)
#
# AttributeError: module 'apecseismicpy.aci350.hydrodynamic' has no attribute 'calculate_heights_of_centers_of_gravity'
