# %%
import apecseismicpy

distance, source_type, soil_type, zone = 2, "A", "sd", 4
site_response = apecseismicpy.site_coefficients(distance, source_type, soil_type,zone)
site_data = site_response.calculate()

na = site_data['na']
nv = site_data['nv']
ca = site_data['ca']
cv = site_data['cv']

print(na)
print(nv)
print(ca)
print(cv)

plot = apecseismicpy.ResponseSpectrum(ca,cv,8.5)
plot.plot()
# Out:
# 1.5
# 2.0
# 0.66
# 1.28
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 17
#      14 print(ca)
#      15 print(cv)
# ---> 17 plot = apecseismicpy.ResponseSpectrum(ca,cv,8.5)
#      18 plot.plot()
#
# TypeError: ResponseSpectrum.__init__() takes 2 positional arguments but 4 were given
