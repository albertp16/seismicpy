# %%
import apecseismicpy

distance, source_type, soil_type, zone = 2, "A", "sd", 4
site_response = apecseismicpy.site_coefficients(distance, source_type, soil_type,zone)
site_data = site_response.calculate()

na = site_data['na']
nv = site_data['nv']
ca = site_data['ca']
cv = site_data['cv']

print(na)
print(nv)
print(ca)
print(cv)

plot = apecseismicpy.ResponseSpectrum(ca,cv)
plot.plot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import apecseismicpy
#       3 distance, source_type, soil_type, zone = 2, "A", "sd", 4
#       4 site_response = apecseismicpy.site_coefficients(distance, source_type, soil_type,zone)
#
# File ~\Desktop\codes\seismicpy\apecseismicpy\__init__.py:1
# ----> 1 from .nscp2015.site_coefficients import site_coefficients
#       2 from .nscp2015.response_spectrum import ResponseSpectrum
#       3 from .nscp2015.period import calculateStructuralPeriod
#
# File ~\Desktop\codes\seismicpy\apecseismicpy\nscp2015\__init__.py:1
# ----> 1 from .response_spectrum import ResponseSpectrum
#       2 from .period import calculateStructuralPeriod
#       3 from .site_coefficients import site_coefficients
#
# ImportError: cannot import name 'ResponseSpectrum' from 'apecseismicpy.nscp2015.response_spectrum' (C:\Users\alber\Desktop\codes\seismicpy\apecseismicpy\nscp2015\response_spectrum.py)
